# %%
#Uploading packaged
import numpy as np
import pylab as pl
import pandas as pd
import datetime as dt
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mp
# Out:
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The pgf.debug rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.

# %%
#reading in csvs#
#clovis
clovis_pm10='aqs_site_06-019-5001_81102.csv'
clovis_pm25='aqs_site_06-019-5001_88101.csv'

#madera
madera_pm10='aqs_site_06-039-2010_81102.csv'
madera_pm25='aqs_site_06-039-2010_88101.csv'

#Table Mountain
tm_pm10='aqs_site_06-019-0500_81102.csv'
tm_pm25='aqs_site_06-019-0500_88101.csv'

#cocoran
cocoran_pm10='aqs_site_06-031-0004_81102.csv'
cocoran_pm25='aqs_site_06-031-0004_88101.csv'

#Sacramento
sac1309_pm10='aqs_site_06-067-0010_81102.csv'
sac1309_pm25='aqs_site_06-067-0010_88101.csv'

#woodland
woodland_pm10='aqs_site_06-113-1003_81102.csv'
woodland_pm25='aqs_site_06-113-1003_88101.csv'

#saving csv file in a dataframe#

#clovis
clovis_pm10_df=pd.read_csv(clovis_pm10)
clovis_pm25_df=pd.read_csv(clovis_pm25)

#madera
madera_pm10_df=pd.read_csv(madera_pm10)
madera_pm25_df=pd.read_csv(madera_pm25)

#Table Mountain
tm_pm10_df=pd.read_csv(tm_pm10)
tm_pm25_df=pd.read_csv(tm_pm25)

#cocoran
cocoran_pm10_df=pd.read_csv(cocoran_pm10)
cocoran_pm25_df=pd.read_csv(cocoran_pm25)

#Sacramento
sac1309_pm10_df=pd.read_csv(sac1309_pm10)
sac1309_pm25_df=pd.read_csv(sac1309_pm25)

#Woodland
woodland_pm10_df=pd.read_csv(woodland_pm10)
woodland_pm25_df=pd.read_csv(woodland_pm25)

# %%
#not yearly data PM 2.5
woodland_pm25_ny=pd.read_csv(woodland_pm25)
sac1309_pm25_ny=pd.read_csv(sac1309_pm25)
cocoran_pm25_ny=pd.read_csv(cocoran_pm25)
tm_pm25_ny=pd.read_csv(tm_pm25)
madera_pm25_ny=pd.read_csv(madera_pm25)
clovis_pm25_ny=pd.read_csv(clovis_pm25)

#datetime
woodland_pm25_ny['datetime_local']=pd.to_datetime(woodland_pm25_ny.datetime_local)
sac1309_pm25_ny['datetime_local']=pd.to_datetime(sac1309_pm25_ny.datetime_local)
clovis_pm25_ny['datetime_local']=pd.to_datetime(clovis_pm25_ny.datetime_local)
cocoran_pm25_ny['datetime_local']=pd.to_datetime(cocoran_pm25_ny.datetime_local)
tm_pm25_ny['datetime_local']=pd.to_datetime(tm_pm25_ny.datetime_local)
madera_pm25_ny['datetime_local']=pd.to_datetime(madera_pm25_ny.datetime_local)

# %%
#saving datetime CM and PM 10
clovis_pm10_df['datetime_local']=pd.to_datetime(clovis_pm10_df.datetime_local)
madera_pm10_df['datetime_local']=pd.to_datetime(madera_pm10_df.datetime_local)
tm_pm10_df['datetime_local']=pd.to_datetime(tm_pm10_df.datetime_local)
cocoran_pm10_df['datetime_local']=pd.to_datetime(cocoran_pm10_df.datetime_local)
sac1309_pm10_df['datetime_local']=pd.to_datetime(sac1309_pm10_df.datetime_local)
woodland_pm10_df['datetime_local']=pd.to_datetime(woodland_pm10_df.datetime_local)

#saving datetime PM 2.5
clovis_pm25_df['datetime_local']=pd.to_datetime(clovis_pm25_df.datetime_local)
madera_pm25_df['datetime_local']=pd.to_datetime(madera_pm25_df.datetime_local)
tm_pm25_df['datetime_local']=pd.to_datetime(tm_pm25_df.datetime_local)
cocoran_pm25_df['datetime_local']=pd.to_datetime(cocoran_pm25_df.datetime_local)
sac1309_pm25_df['datetime_local']=pd.to_datetime(sac1309_pm25_df.datetime_local)
woodland_pm25_df['datetime_local']=pd.to_datetime(woodland_pm25_df.datetime_local)

# %%
#making year column
#Making year column CM
clovis_pm10_df['year']=clovis_pm10_df.datetime_local.dt.year
madera_pm10_df['year']=madera_pm10_df.datetime_local.dt.year
tm_pm10_df['year']=tm_pm10_df.datetime_local.dt.year
cocoran_pm10_df['year']=cocoran_pm10_df.datetime_local.dt.year
sac1309_pm10_df['year']=sac1309_pm10_df.datetime_local.dt.year
woodland_pm10_df['year']=woodland_pm10_df.datetime_local.dt.year

#Making year column PM 2.5
clovis_pm25_df['year']=clovis_pm25_df.datetime_local.dt.year
madera_pm25_df['year']=madera_pm25_df.datetime_local.dt.year
tm_pm25_df['year']=tm_pm25_df.datetime_local.dt.year
cocoran_pm25_df['year']=cocoran_pm25_df.datetime_local.dt.year
sac1309_pm25_df['year']=sac1309_pm25_df.datetime_local.dt.year
woodland_pm25_df['year']=woodland_pm25_df.datetime_local.dt.year

# %%
#Making year column CM
clovis_pm10_df['year']=clovis_pm10_df.datetime_local.dt.year
madera_pm10_df['year']=madera_pm10_df.datetime_local.dt.year
tm_pm10_df['year']=tm_pm10_df.datetime_local.dt.year
cocoran_pm10_df['year']=cocoran_pm10_df.datetime_local.dt.year
sac1309_pm10_df['year']=sac1309_pm10_df.datetime_local.dt.year
woodland_pm10_df['year']=woodland_pm10_df.datetime_local.dt.year

#Making year column PM 2.5
clovis_pm25_df['year']=clovis_pm25_df.datetime_local.dt.year
madera_pm25_df['year']=madera_pm25_df.datetime_local.dt.year
tm_pm25_df['year']=tm_pm25_df.datetime_local.dt.year
cocoran_pm25_df['year']=cocoran_pm25_df.datetime_local.dt.year
sac1309_pm25_df['year']=sac1309_pm25_df.datetime_local.dt.year
woodland_pm25_df['year']=woodland_pm25_df.datetime_local.dt.year

# %%
#making averages 
clovis_pm25_df=clovis_pm25_df.groupby('year').mean().reset_index()
madera_pm25_df=madera_pm25_df.groupby('year').mean().reset_index()
tm_pm25_df=tm_pm25_df.groupby('year').mean().reset_index()
cocoran_pm25_df=cocoran_pm25_df.groupby('year').mean().reset_index()
sac1309_pm25_df=sac1309_pm25_df.groupby('year').mean().reset_index()
woodland_pm25_df=woodland_pm25_df.groupby('year').mean().reset_index()

# %%
#doing fractions
clovis_pm25_df['PM Ratio 2.5 to 10 x'] = clovis_pm25_df.sample_measurement / clovis_pm10_df.sample_measurement

# %%
tm_pm25_df['PM Ratio 2.5 to 10 x'] = tm_pm25_df.sample_measurement / tm_pm10_df.sample_measurement

# %%
sac1309_pm25_df['PM Ratio 2.5 to 10 x'] = sac1309_pm25_df.sample_measurement / sac1309_pm10_df.sample_measurement

# %%
cocoran_pm25_df['PM Ratio 2.5 to 10 x'] = cocoran_pm25_df.sample_measurement / cocoran_pm10_df.sample_measurement

# %%
madera_pm25_df['PM Ratio 2.5 to 10 x'] = madera_pm25_df.sample_measurement / madera_pm10_df.sample_measurement

# %%
woodland_pm25_df['PM Ratio 2.5 to 10 x'] = woodland_pm25_df.sample_measurement / woodland_pm10_df.sample_measurement

# %%
#Clovis
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(clovis_pm25_df['year'], clovis_pm25_df['PM Ratio 2.5 to 10 x'], alpha=opacity, color='red', label='2013')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("Clovis, CA Annual Fractions 2013-2021")
#plt.legend()
plt.tight_layout()
plt.show()

# %%
#tm
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(tm_pm25_df['year'], tm_pm25_df['PM Ratio 2.5 to 10 x'], alpha=opacity, color='red', label='2013')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("tm, CA Annual Fractions 2013-2021")
#plt.legend()
plt.tight_layout()
plt.show()

# %%
#sac1309
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(sac1309_pm25_df['year'], sac1309_pm25_df['PM Ratio 2.5 to 10 x'], alpha=opacity, color='red', label='2013')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("sac1309, CA Annual Fractions 2013-2021")
#plt.legend()
plt.tight_layout()
plt.show()

# %%
#madera
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(madera_pm25_df['year'], madera_pm25_df['PM Ratio 2.5 to 10 x'], alpha=opacity, color='red', label='2013')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("madera, CA Annual Fractions 2013-2021")
#plt.legend()
plt.tight_layout()
plt.show()

# %%
#woodland
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(woodland_pm25_df['year'], woodland_pm25_df['PM Ratio 2.5 to 10 x'], alpha=opacity, color='red')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("woodland, CA Annual Fractions 2013-2021")
#plt.legend()
plt.tight_layout()
plt.show()

# %%
#cocoran
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(cocoran_pm25_df['year'], cocoran_pm25_df['PM Ratio 2.5 to 10 x'], alpha=opacity, color='red')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("cocoran, CA Annual Fractions 2013-2021")
#plt.legend()
plt.tight_layout()
plt.show()

# %%
#All on one plot
#bar
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(clovis_pm25_df['year'], clovis_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.2, color='red', label='Clovis')
plt.bar(tm_pm25_df['year'], tm_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.4, color='orange', label='Table Mountain')
plt.bar(sac1309_pm25_df['year'], sac1309_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.4, color='yellow', label='Sacramento')
plt.bar(madera_pm25_df['year'], madera_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.6, color='green', label='Madera')
plt.bar(woodland_pm25_df['year'], woodland_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.1, color='blue', label='Woodland')
plt.bar(cocoran_pm25_df['year'], cocoran_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='purple', label='Cocoran')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("Annual Fractions of PM in California 2013-2021")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Plotting centrals
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(clovis_pm25_df['year'], clovis_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.2, color='red', label='Clovis')
plt.bar(tm_pm25_df['year'], tm_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.4, color='orange', label='Table Mountain')
plt.bar(madera_pm25_df['year'], madera_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.6, color='green', label='Madera')
plt.bar(cocoran_pm25_df['year'], cocoran_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.6, color='purple', label='Cocoran')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("Annual Fractions of PM in Central California 2013-2021")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Plotting sacramento sites
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.bar(sac1309_pm25_df['year'], sac1309_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='grey', label='Sacramento')
plt.bar(woodland_pm25_df['year'], woodland_pm25_df['PM Ratio 2.5 to 10 x'], alpha=.5, color='blue', label='Woodland')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("Annual Fractions of PM near Sacramento, California 2013-2021")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#All on one plot
#bar
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.scatter(clovis_pm25_df['year'], clovis_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='red', label='Clovis', marker='^')
plt.scatter(tm_pm25_df['year'], tm_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='orange', label='Table Mountain', marker='^')
plt.scatter(sac1309_pm25_df['year'], sac1309_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='yellow', label='Sacramento', marker='^')
plt.scatter(madera_pm25_df['year'], madera_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='green', label='Madera', marker='^')
plt.scatter(woodland_pm25_df['year'], woodland_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='blue', label='Woodland', marker='^')
plt.scatter(cocoran_pm25_df['year'], cocoran_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='purple', label='Cocoran', marker='^')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("Annual Fractions of PM in California 2013-2021")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#All on one plot
#bar
fg, ax=plt.subplots()
bar_width=0.3
opacity=0.4
plt.plot(clovis_pm25_df['year'], clovis_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='red', label='Clovis')
plt.plot(tm_pm25_df['year'], tm_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='orange', label='Table Mountain')
plt.plot(sac1309_pm25_df['year'], sac1309_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='yellow', label='Sacramento')
plt.plot(madera_pm25_df['year'], madera_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='green', label='Madera',)
plt.plot(woodland_pm25_df['year'], woodland_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='blue', label='Woodland')
plt.plot(cocoran_pm25_df['year'], cocoran_pm25_df['PM Ratio 2.5 to 10 x'], alpha=1, color='purple', label='Cocoran')
plt.xlabel('Year')
plt.ylabel('PM in micrograms per cubic meter')
plt.ylim(0,4.5)
plt.xlim(2012,2022)
plt.title("Annual Fractions of PM in California 2013-2021")
plt.legend()
plt.tight_layout()
plt.show()
